# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.ambitionbox.com/list-of-companies?campaign=homepage_companies_widget&page=1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}
page = requests.get(URL, headers=headers).text

# %%
soup=BeautifulSoup(page,'lxml')

# %%
company = soup.find_all('div', class_='company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name=[]

for i in company:
    name.append(i.find('h2').text.strip())

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'ICICI Bank',
#  'HDFC Bank',
#  'Wipro',
#  'Infosys',
#  'Capgemini',
#  'Tech Mahindra',
#  'Genpact',
#  'HCLTech',
#  'Amazon',
#  'Axis Bank',
#  'IBM',
#  'Concentrix Corpo...',
#  'Reliance jio',
#  'Larsen & Toubro ...',
#  'Vodafone Idea',
#  'HDB Financial Se...',
#  'Teleperformance',
#  'Kotak Mahindra B...',
#  'Reliance Industr...',
#  'Bharti Airtel',
#  'Deloitte',
#  'Reliance Retail',
#  'Tata Motors',
#  'WNS',
#  'Mahindra & Mahin...',
#  'IndusInd Bank',
#  "BYJU'S"]

# %%
rating=[]

for i in company:
    rating.append(i.find('p', class_='rating').text.strip())

# %%
rating
# Out:
# ['3.9',
#  '4.2',
#  '3.9',
#  '4.0',
#  '4.0',
#  '3.9',
#  '3.9',
#  '3.9',
#  '3.7',
#  '4.0',
#  '3.8',
#  '4.3',
#  '3.9',
#  '4.2',
#  '4.1',
#  '4.0',
#  '4.1',
#  '4.2',
#  '4.0',
#  '3.6',
#  '3.9',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '3.7',
#  '3.9',
#  '3.8',
#  '3.5']

# %%
reviews=[]

for i in company:
    reviews.append(i.find('a', class_='review-count').text.strip())

# %%
reviews
# Out:
# ['(49.3k Reviews)',
#  '(32.2k Reviews)',
#  '(29.4k Reviews)',
#  '(34.7k Reviews)',
#  '(39.6k Reviews)',
#  '(28.5k Reviews)',
#  '(28k Reviews)',
#  '(23.8k Reviews)',
#  '(21.7k Reviews)',
#  '(20.9k Reviews)',
#  '(18.3k Reviews)',
#  '(18.1k Reviews)',
#  '(19k Reviews)',
#  '(15.6k Reviews)',
#  '(15.3k Reviews)',
#  '(15k Reviews)',
#  '(24.7k Reviews)',
#  '(13.9k Reviews)',
#  '(13.3k Reviews)',
#  '(14.3k Reviews)',
#  '(13.7k Reviews)',
#  '(43.5k Reviews)',
#  '(12.8k Reviews)',
#  '(10.2k Reviews)',
#  '(15.5k Reviews)',
#  '(12.4k Reviews)',
#  '(7k Reviews)',
#  '(39.4k Reviews)',
#  '(6.8k Reviews)',
#  '(11.6k Reviews)']

# %%
companytype=[]

for i in company:
    companytype.append(i.find_all('p', class_='infoEntity')[0].text.strip())

# %%
companytype
# Out:
# ['Public',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Public',
#  'Public',
#  'Private',
#  'Private',
#  'Public',
#  'Private',
#  'Public',
#  'Public',
#  'Private']

# %%
headquarters=[]

for i in company:
    headquarters.append(i.find_all('p', class_='infoEntity')[1].text.strip())

# %%
headquarters
# Out:
# ['Mumbai,Maharashtra + 272 more',
#  'Dublin + 141 more',
#  'Teaneck. New Jersey. + 97 more',
#  'Mumbai,Maharashtra + 1035 more',
#  'Mumbai,Maharashtra + 1206 more',
#  'Bangalore/Bengaluru,Karnataka + 231 more',
#  'Bengaluru/Bangalore,Karnataka + 124 more',
#  'Paris + 78 more',
#  'Pune,Maharashtra + 212 more',
#  'New York,New York + 66 more',
#  'Noida + 141 more',
#  'Seattle,Washington + 383 more',
#  'Mumbai,Maharashtra + 1068 more',
#  'Armonk,New York + 119 more',
#  'Fremont,California + 68 more',
#  'Navi Mumbai,Maharashtra + 959 more',
#  'Mumbai,Maharashtra + 521 more',
#  'Gandhinagar,Gujrat + 561 more',
#  'Ahmedabad,Gujrat + 770 more',
#  'Paris + 122 more',
#  'Mumbai,Maharashtra + 469 more',
#  'Navi Mumbai,Maharashtra + 479 more',
#  'Gurgaon/Gurugram,Haryana + 507 more',
#  'New York,New York + 133 more',
#  'Navi Mumbai,Maharashtra + 636 more',
#  'Pune,Maharashtra + 390 more',
#  'Mumbai,Maharashtra + 22 more',
#  'Mumbai,Maharashtra + 408 more',
#  'Gurgaon/Gurugram,Haryana + 553 more',
#  'Bangalore,Karnataka + 189 more']

# %%
old=[]

for i in company:
    old.append(i.find_all('p', class_='infoEntity')[2].text.strip())

# %%
old
# Out:
# ['54 years old',
#  '33 years old',
#  '28 years old',
#  '28 years old',
#  '28 years old',
#  '77 years old',
#  '41 years old',
#  '55 years old',
#  '36 years old',
#  '25 years old',
#  '31 years old',
#  '28 years old',
#  '29 years old',
#  '111 years old',
#  '39 years old',
#  '15 years old',
#  '84 years old',
#  '4 years old',
#  '15 years old',
#  '44 years old',
#  '19 years old',
#  '49 years old',
#  '27 years old',
#  '177 years old',
#  '16 years old',
#  '77 years old',
#  '26 years old',
#  '77 years old',
#  '28 years old',
#  '11 years old']

# %%
employees=[]

for i in company:
    try:
        employees.append(i.find_all('p', class_='infoEntity')[3].text.strip())
    except:
        employees.append(np.nan)

# %%
employees
# Out:
# ['1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '10k-50k Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '10k-50k Employees (India)',
#  '10k-50k Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '10k-50k Employees (India)',
#  '50k-1 Lakh Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '10k-50k Employees (India)',
#  '10k-50k Employees (India)',
#  '1 Lakh+ Employees (India)',
#  '10k-50k Employees (India)',
#  '1k-5k Employees (India)']

# %%
name = []
rating=[]
reviews=[]
companytype=[]
headquarters=[]
old=[]
employees=[]
for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p', class_='rating').text.strip())
    reviews.append(i.find('a', class_='review-count').text.strip())
    companytype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
    headquarters.append(i.find_all('p', class_='infoEntity')[1].text.strip())
    old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
    try:
        employees.append(i.find_all('p', class_='infoEntity')[3].text.strip())
    except:
        employees.append(np.nan)
    
d = {'Name':name, 'Rating':rating, 'Reviews':reviews, 'Company Type':companytype, 'Headquarters':headquarters, 'Company Age':old, 'No. of Employees':employees}
df=pd.DataFrame(d)
df
# Out:
#                    Name Rating          Reviews Company Type  \
# 0                   TCS    3.9  (49.3k Reviews)       Public
# 1             Accenture    4.2  (32.2k Reviews)       Public
# 2             Cognizant    3.9  (29.4k Reviews)      Private
# 3            ICICI Bank    4.0  (34.7k Reviews)       Public
# 4             HDFC Bank    4.0  (39.6k Reviews)       Public
# 5                 Wipro    3.9  (28.5k Reviews)       Public
# 6               Infosys    3.9    (28k Reviews)       Public
# 7             Capgemini    3.9  (23.8k Reviews)       Public
# 8         Tech Mahindra    3.7  (21.7k Reviews)       Public
# 9               Genpact    4.0  (20.9k Reviews)       Public
# 10              HCLTech    3.8  (18.3k Reviews)       Public
# 11               Amazon    4.3  (18.1k Reviews)       Public
# 19  50k-1 Lakh Employees (India)
# 20  50k-1 Lakh Employees (India)
# 21     1 Lakh+ Employees (India)
# 22     10k-50k Employees (India)
# 23  50k-1 Lakh Employees (India)
# 24     1 Lakh+ Employees (India)
# 25     10k-50k Employees (India)
# 26     10k-50k Employees (India)
# 27     1 Lakh+ Employees (India)
# 28     10k-50k Employees (India)
# 29       1k-5k Employees (India)

# %%
final=pd.DataFrame()
for j in range(1,333):
    URL = 'https://www.ambitionbox.com/list-of-companies?campaign=homepage_companies_widget&page={}'.format(j)
    
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}
    page = requests.get(URL, headers=headers).text
    
    soup=BeautifulSoup(page,'lxml')
    company = soup.find_all('div', class_='company-content-wrapper')
    
    name = []
    rating=[]
    reviews=[]
    companytype=[]
    headquarters=[]
    old=[]
    employees=[]
    
    for i in company:
        name.append(i.find('h2').text.strip())
        try:
            rating.append(i.find('p', class_='rating').text.strip())
        except:
            rating.append(np.nan)
        try:
            reviews.append(i.find('a', class_='review-count').text.strip())
        except:
            reviews.append(np.nan)
        try:
            companytype.append(i.find_all('p', class_='infoEntity')[0].text.strip())
        except:
            companytype.append(np.nan)
        try:
            headquarters.append(i.find_all('p', class_='infoEntity')[1].text.strip())
        except:
            headquarters.append(np.nan)
        try:
            old.append(i.find_all('p', class_='infoEntity')[2].text.strip())
        except:
            old.append(np.nan)
        try:
            employees.append(i.find_all('p', class_='infoEntity')[3].text.strip())
        except:
            employees.append(np.nan)
    

    d = {'Name':name, 'Rating':rating, 'Reviews':reviews, 'Company Type':companytype, 'Headquarters':headquarters, 'Company Age':old, 'No. of Employees':employees}
    df=pd.DataFrame(d)
    final=pd.concat([final, df])

# %%
final.shape
# Out:
# (9958, 7)

# %%
final
# Out:
#                    Name Rating          Reviews                 Company Type  \
# 0                   TCS    3.9  (49.3k Reviews)                       Public
# 1             Accenture    4.2  (32.2k Reviews)                       Public
# 2             Cognizant    3.9  (29.4k Reviews)                      Private
# 3            ICICI Bank    4.0  (34.7k Reviews)                       Public
# 4             HDFC Bank    4.0  (39.6k Reviews)                       Public
# ..                  ...    ...              ...                          ...
# 25       Aruba Networks    3.9     (52 Reviews)                      Private
# 26  Consulting Engin...    4.8     (52 Reviews)                      Private
# 27  Transparency Mar...    2.9     (52 Reviews)                      Private
# 28  Mckinsey Knowled...    4.2     (52 Reviews)  Chennai,Tamil Nadu + 4 more
# 29  Virtuoso Project...    3.6     (52 Reviews)                         Pune
#
#                        Headquarters               Company Age  \
# 0     Mumbai,Maharashtra + 272 more              54 years old
# 1                 Dublin + 141 more              33 years old
# 2    Teaneck. New Jersey. + 97 more              28 years old
# 3    Mumbai,Maharashtra + 1035 more              28 years old
# 4    Mumbai,Maharashtra + 1206 more              28 years old
# ..                              ...                       ...
# 25  Santa Clara,California + 1 more              20 years old
# 26                 Jaipur + 16 more              53 years old
# 27         Albany,New York + 1 more              11 years old
# 28                     24 years old   1k-5k Employees (India)
# 29                     11 years old  51-200 Employees (India)
#
#              No. of Employees
# 0   1 Lakh+ Employees (India)
# 1   1 Lakh+ Employees (India)
# 2   1 Lakh+ Employees (India)
# 3   1 Lakh+ Employees (India)
# 4   1 Lakh+ Employees (India)
# ..                        ...
# 25   501-1k Employees (India)
# 26   1k-5k Employees (Global)
# 27     1-10 Employees (India)
# 28                        NaN
# 29                        NaN
#
# [9958 rows x 7 columns]
